# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn

# %%
file_path = "/Users/aryellewright/Documents/Kumar-Biomaterials-Lab/CCK8_Assay_Plots/20230915_CellCulture_DIP70equivtransfection copy.xlsx" 
sheet_name = "Sheet2"  

df = pd.read_excel(file_path, sheet_name=sheet_name)
# print(df.head())

# %%
variable = df['Variables'][::-1]
viability = df['Viability']
std_devs = df['Standard Deviation']

#print(std_devs)

# %%
plt.barh(variable, viability, xerr=std_devs, capsize = 3, color='navy')
plt.xlabel('% Viability')
#plt.ylabel('')

plt.title('DIP70 Equiv CCK8 Assay Viability')
plt.show()
