# %%
# imports imports imports
from create_dsf_graphs import create_dsf_graphs
import pandas
import matplotlib.pyplot
import csv

# %%
urlfile='/Applications/Aryelle-Plots/melting_point/raw_data/20221217_Cas9_AW_RK__new.csv'

create_dsf_graphs(urlfile)
# Out:
# /Applications/Aryelle-Plots/melting_point/camdens_smart/create_dsf_graphs.py:13: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df = df.groupby("SamplePos")["Temp", '465-580'].agg(list)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 urlfile='/Applications/Aryelle-Plots/melting_point/raw_data/20221217_Cas9_AW_RK__new.csv'
#       2 if __name__ == '__main__':
# ----> 3     create_dsf_graphs(urlfile)
#
# File /Applications/Aryelle-Plots/melting_point/camdens_smart/create_dsf_graphs.py:85, in create_dsf_graphs(filename)
#      81 melting_curve_plot.set_xlabel('Temperature (°C)')
#      83 # plotting our derivative plot
#      84 derivative_plot = derivative_df.plot(x='Temperature Celsius',
# ---> 85                                 y=derivative_data[1::],
#      86                                 kind='line',
#      87                                 legend=True,
#      88                                 linewidth=0.1)
#      89 derivative_plot.set_ylabel('dRU/dt')
#      90 derivative_plot.set_xlabel('Temperature (°C)')
#
# TypeError: unhashable type: 'slice'
