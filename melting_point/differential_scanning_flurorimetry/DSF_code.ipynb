# %%
# imports imports imports
from create_dsf_graphs import create_dsf_graphs
import pandas
import matplotlib.pyplot
import csv

# %%
urlfile='/Applications/Aryelle-Plots/melting_point/raw_data/20221217_Cas9_AW_RK__new.csv'

create_dsf_graphs(urlfile)
# Out:
# /Applications/Aryelle-Plots/melting_point/camdens_smart/create_dsf_graphs.py:16: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df = df.groupby('SamplePos')['Temp', '465-580'].agg(list)
# /var/folders/_4/p4fjmvxj58b0rwrppg_ly3_m0000gn/T/ipykernel_9540/3292102171.py:3: RankWarning: Polyfit may be poorly conditioned
#   create_dsf_graphs(urlfile)
# /var/folders/_4/p4fjmvxj58b0rwrppg_ly3_m0000gn/T/ipykernel_9540/3292102171.py:3: RankWarning: Polyfit may be poorly conditioned
#   create_dsf_graphs(urlfile)
# /var/folders/_4/p4fjmvxj58b0rwrppg_ly3_m0000gn/T/ipykernel_9540/3292102171.py:3: RankWarning: Polyfit may be poorly conditioned
#   create_dsf_graphs(urlfile)
